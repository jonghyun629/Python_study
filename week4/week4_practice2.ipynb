# %% [markdown]
# # 🏋️ Practice Tasks (Day 2)
#
# 1. Write a function `multiply(a, b)` that **returns** the product of two numbers.
#
# 2. Write a function `square_and_cube(n)` that returns **both the square and cube** of a number.
#
# 3. Show the difference between a **local and global variable** with the same name.
#
# 4. (Challenge 💡) Write a function `circle_stats(radius)` that returns **both area and circumference** of a circle (πr² and 2πr).

# %%
# 1. Write a function multiply(a, b) that returns the product of two numbers.

def multiply(a, b):
  return a*b

a = int(input('Enter a number: '))
b = int(input('Enter a number: '))

multiply(a, b)
# Out:
# Enter a number: 3
# Enter a number: 4
# 12

# %%
# 2. Write a function square_and_cube(n) that returns both the square and cube of a number.

def square_and_cube(n):
  return n**2, n**3

num = int(input('Enter a number: '))
print(square_and_cube(num))
# Out:
# Enter a number: 2
# (4, 8)

# %%
# 3. Show the difference between a local and global variable with the same name.

outside = 'Roy'

def inside():
  name = 'Roy'
  return name

print(outside)
print(inside())
# Out:
# Roy
# Roy

# %%
'''
4. (Challenge 💡) Write a function circle_stats(radius) that returns both area and circumference of a circle (πr² and 2πr).
'''

def circle_stats(radius):
  return 3.14*radius**2, 2*3.14*radius

radius = int(input('Enter a radius: '))
print(circle_stats(radius))
# Out:
# Enter a radius: 4
# (50.24, 25.12)
