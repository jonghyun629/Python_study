# %% [markdown]
# # 📝 Practice (Day 3)

# %% [markdown]
# 1. Use a loop with `break`: print numbers 1 → 10, but stop if you reach 7.

# %%
for i in range(1, 11):
  if i == 7:
    break
  print(i)
  i =+ 1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# 2. Use a loop with `continue`: print numbers 1 → 10, but skip 5.

# %%
for i in range(1, 11):
  if i == 5:
    continue
  print(i)
  i =+ 1
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10

# %% [markdown]
# 3. Use a **nested loop** to print all pairs of numbers from 1–3:
#
# (1,1) (1,2) (1,3)
#
# (2,1) (2,2) (2,3)
#
# (3,1) (3,2) (3,3)

# %%
for i in range(1,4):
  for j in range(1,4):
    print(f"({i},{j})", end = " ")
    if j ==3:
      print()
# Out:
# (1,1) (1,2) (1,3)
# (2,1) (2,2) (2,3)
# (3,1) (3,2) (3,3)

# %% [markdown]
# 4. (Challenge 💡) Build a 3x3 star pattern using nested loops:

# %%
for i in range(1,4):
  print('*' * 3)
# Out:
# ***
# ***
# ***
