# %% [markdown]
# #📌Week 1: Variables & Data Types

# %% [markdown]
# ---

# %% [markdown]
# ## In Python:
# - A **variable** is like a box that holds information.
# - A **data type** tells us what kind of information is inside.

# %% [markdown]
# ---

# %%
# Example

name = "Roy"        # string (text)
age = 25            # integer (whole number)
height = 175.5      # float (decimal)
is_student = True   # boolean (True/False)

print(name)
print(age)
print(height)
print(is_student)
# Out:
# Roy
# 25
# 175.5
# True

# %%
# Exercise 1

color = 'Black'
age = 25
python = True

print(f"My favorite color is {color}")
print(f"My age is {age}")
print(f"I am learning Python: {python}")
# Out:
# My favorite color is Black
# My age is 25
# I am learning Python: True

# %%
# Exercise 2

first_name = 'Roy'
last_name = 'Lee'
birth_year = 2000
height = 175.5
is_teacher = True

print(f"My name is {first_name} {last_name}")
print(f"My birth year is {birth_year}")
print(f"My height is {height}")
print(f"I am a teacher: {is_teacher}")
# Out:
# My name is Roy Lee
# My birth year is 2000
# My height is 175.5
# I am a teacher: True

# %%
# Exercise 3

current_year = 2025
birth_year = 2000
age = current_year - birth_year

print(f'Hello, my name is Roy. I am {age} years old.')
# Out:
# Hello, my name is Roy. I am 25 years old.

# %%
# Week 1 precap

current_year = 2025

name = input("Enter your name: ")
birth_year = int(input("Enter your birth year: "))
color = input("Enter your favorite color: ")
likes_python = input("Do you like Python? (yes/no): ")

# Calculate age
age = current_year - birth_year

# Convert input to boolean
if likes_python.lower() == "yes":
    likes_python = True
else:
    likes_python = False

# Print info card
print("\n--- Personal Info Card ---")
print(f"Name: {name}")
print(f"Age: {age}")
print(f"Favorite Color: {color}")
print(f"Likes Python: {likes_python}")
print("--------------------------")
# Out:
# Enter your name: ROy
# Enter your birth year: 2000
# Enter your favorite color: Bkack
# Do you like Python? (yes/no): yes
#
# --- Personal Info Card ---
# Name: ROy
# Age: 25
# Favorite Color: Bkack
# Likes Python: True
# --------------------------

# %% [markdown]
# ---

# %% [markdown]
# ## 🌡️Project: Temperature Converter
#
# Your program should:
# - Ask the user to type a temperature in Celsius.
# - Convert it to Fahrenheit.
# - Print the result nicely.
# - (Bonus) Do the reverse: Fahrenheit → Celsius.

# %%
# Ask temperature in Celsius or Fahrenheit
choice = input("Convert from (C)elsius or (F)ahrenheit? ").lower()

# Convert temp
if choice == 'c':
    c = float(input("Enter Celsius: "))
    f = (c * 9/5) + 32
    print(f"{c:.2f}°C = {f:.2f}°F")
elif choice == 'f':
    f = float(input("Enter Fahrenheit: "))
    c = (f - 32) * 5/9
    print(f"{f:.2f}°F = {c:.2f}°C")
else:
    print("Invalid choice.")
# Out:
# Convert from (C)elsius or (F)ahrenheit? C
# Enter Celsius: 32
# 32.00°C = 89.60°F

# %% [markdown]
# ---

# %% [markdown]
# ## 🎲 Week 1 Final Challenge Project: Simple Calculator
#
# ### 📌 Requirements
#
# - Ask the user for two numbers.
#
# - Ask the user to choose an operation: add, subtract, multiply, divide.
#
# - Perform the calculation and print the result.
#
# - (Bonus) Keep running until the user types "exit".

# %%
def cal():
    while True:  # keep running until break
        # Asking the user for two numbers
        num1 = float(input('Enter a number: '))
        num2 = float(input('Enter another number: '))

        # Choosing an operation
        operation = int(input('Enter 1 for addition, 2 for subtraction, 3 for multiplication, 4 for division, 5 to exit: '))

        # Function
        if operation == 1:
            print(f"{num1} + {num2} = {num1 + num2}")
        elif operation == 2:
            print(f"{num1} - {num2} = {num1 - num2}")
        elif operation == 3:
            print(f"{num1} * {num2} = {num1 * num2}")
        elif operation == 4:
            if num2 == 0:
                print("Error: Cannot divide by zero!")
            else:
                print(f"{num1} / {num2} = {num1 / num2}")
        elif operation == 5:
            print("Exiting calculator... Goodbye!")
            break
        else:
            print("Invalid operation, please choose 1–5")

# Run it
cal()
# Out:
# Enter a number: 3
# Enter another number: 4
# Enter 1 for addition, 2 for subtraction, 3 for multiplication, 4 for division, 5 to exit: 5
# Exiting calculator... Goodbye!
